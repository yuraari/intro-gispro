# %% [markdown]
# # Vector Data Analysis with GeoPandas
#
# ## Introduction
#
# ## Learning Objectives
#
# ## Core Concepts
#
# ### GeoDataFrame and GeoSeries
#
# ### Active Geometry Concept
#
# ## Installing GeoPandas

# %%
# %pip install geopandas pygis
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (1.1.3)
# Collecting pygis
#   Downloading pygis-0.10.2-py2.py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas) (0.12.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas) (26.1)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas) (2.1.2)
# Collecting anymap (from pygis)
#   Downloading anymap-0.12.0-py2.py3-none-any.whl.metadata (6.8 kB)
# Collecting bash_kernel (from pygis)
#   Downloading bash_kernel-0.10.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: duckdb in /usr/local/lib/python3.12/dist-packages (from pygis) (1.3.2)
# Collecting duckdb-engine (from pygis)
#   Downloading duckdb_engine-0.17.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting ffmpeg-python (from pygis)
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting geeadd (from pygis)
#   Downloading geeadd-2.1.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: geemap>=0.36.6 in /usr/local/lib/python3.12/dist-packages (from pygis) (0.37.2)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from pygis) (6.17.1)
# Collecting jupysql (from pygis)
#   Downloading jupysql-0.11.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting jupyter-server-proxy (from pygis)
#   Downloading jupyter_server_proxy-4.5.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting leafmap>=0.57.9 (from pygis)
#   Downloading leafmap-0.62.0-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.12/dist-packages (from pygis) (2.10.0)
# Collecting maplibre (from pygis)
#   Downloading maplibre-0.3.6-py3-none-any.whl.metadata (4.2 kB)
# Collecting mapwidget (from pygis)
#   Downloading mapwidget-0.2.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting planetary-computer (from pygis)
#   Downloading planetary_computer-1.0.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting pmtiles (from pygis)
#   Downloading pmtiles-3.7.0-py3-none-any.whl.metadata (903 bytes)
# Requirement already satisfied: pooch in /usr/local/lib/python3.12/dist-packages (from pygis) (1.9.0)
# Collecting solara (from pygis)
#   Downloading solara-1.57.4-py3-none-any.whl.metadata (10 kB)
# Collecting voila (from pygis)
#   Downloading voila-0.5.12-py3-none-any.whl.metadata (9.4 kB)
# Collecting voila-topbar (from pygis)
#   Downloading voila_topbar-0.1.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting whiteboxgui (from pygis)
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: xarray in /usr/local/lib/python3.12/dist-packages (from pygis) (2025.12.0)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (0.9.21)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (0.12.45)
# Requirement already satisfied: earthengine-api>=1.6.12 in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (1.7.22)
# Requirement already satisfied: eerepr>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (0.1.2)
# Requirement already satisfied: folium>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (0.20.0)
# Requirement already satisfied: geocoder in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (1.38.1)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (2.0.4)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (0.6.0)
# Requirement already satisfied: ipyleaflet>=0.19.2 in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (0.20.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (3.10.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (5.24.1)
# Requirement already satisfied: pyperclip in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (1.11.0)
# Requirement already satisfied: pyshp>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (3.0.3)
# Requirement already satisfied: python-box in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (7.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (2.32.4)
# Requirement already satisfied: scooby in /usr/local/lib/python3.12/dist-packages (from geemap>=0.36.6->pygis) (0.11.2)
# Collecting duckdb (from pygis)
#   Downloading duckdb-1.5.2-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.9->pygis) (5.2.2)
# Collecting geojson (from leafmap>=0.57.9->pygis)
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Collecting ipyvue>=1.12.0 (from leafmap>=0.57.9->pygis)
#   Downloading ipyvue-1.12.0-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting ipyvuetify (from leafmap>=0.57.9->pygis)
#   Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.9->pygis) (7.7.1)
# Collecting pystac-client (from leafmap>=0.57.9->pygis)
#   Downloading pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.9->pygis) (2026.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->geopandas) (2026.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas) (2026.4.22)
# Collecting ipywidgets (from leafmap>=0.57.9->pygis)
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from anymap->pygis) (5.9.5)
# Requirement already satisfied: traitlets>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from anymap->pygis) (5.7.1)
# Requirement already satisfied: pexpect>=4.0 in /usr/local/lib/python3.12/dist-packages (from bash_kernel->pygis) (4.9.0)
# Collecting filetype (from bash_kernel->pygis)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: sqlalchemy>=1.3.22 in /usr/local/lib/python3.12/dist-packages (from duckdb-engine->pygis) (2.0.49)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from ffmpeg-python->pygis) (1.0.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from geeadd->pygis) (8.3.3)
# Collecting colorama>=0.4.6 (from geeadd->pygis)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: google-auth>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geeadd->pygis) (2.47.0)
# Collecting jsbeautifier>=1.15.1 (from geeadd->pygis)
#   Downloading jsbeautifier-1.15.4-py3-none-any.whl.metadata (374 bytes)
# Requirement already satisfied: rich>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from geeadd->pygis) (13.9.4)
# Requirement already satisfied: tqdm>=4.66.5 in /usr/local/lib/python3.12/dist-packages (from geeadd->pygis) (4.67.3)
# Requirement already satisfied: urllib3>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geeadd->pygis) (2.5.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygis) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygis) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygis) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygis) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygis) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygis) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->pygis) (6.5.1)
# Requirement already satisfied: prettytable>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from jupysql->pygis) (3.17.0)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.12/dist-packages (from jupysql->pygis) (0.5.5)
# Requirement already satisfied: ipython-genutils>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from jupysql->pygis) (0.2.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from jupysql->pygis) (3.1.6)
# Requirement already satisfied: sqlglot>=11.3.7 in /usr/local/lib/python3.12/dist-packages (from jupysql->pygis) (25.20.2)
# Collecting jupysql-plugin>=0.4.2 (from jupysql->pygis)
#   Downloading jupysql_plugin-0.4.5-py3-none-any.whl.metadata (7.8 kB)
# Collecting ploomber-core>=0.2.7 (from jupysql->pygis)
#   Downloading ploomber_core-0.2.27-py3-none-any.whl.metadata (532 bytes)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->pygis) (3.13.5)
# Requirement already satisfied: jupyter-server>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->pygis) (2.14.0)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy->pygis)
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.12/dist-packages (from mapclassify->pygis) (3.6.1)
# Requirement already satisfied: scikit-learn>=1.4 in /usr/local/lib/python3.12/dist-packages (from mapclassify->pygis) (1.6.1)
# Requirement already satisfied: scipy>=1.12 in /usr/local/lib/python3.12/dist-packages (from mapclassify->pygis) (1.16.3)
# Requirement already satisfied: branca in /usr/local/lib/python3.12/dist-packages (from maplibre->pygis) (0.8.2)
# Collecting eval-type-backport (from maplibre->pygis)
#   Downloading eval_type_backport-0.3.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pydantic>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from maplibre->pygis) (2.12.3)
# Collecting pystac>=1.0.0 (from planetary-computer->pygis)
#   Downloading pystac-1.14.3-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from planetary-computer->pygis) (1.2.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch->pygis) (4.9.6)
# Collecting solara-server==1.57.4 (from solara-server[dev,starlette]==1.57.4->solara->pygis)
#   Downloading solara_server-1.57.4-py3-none-any.whl.metadata (2.9 kB)
# Collecting solara-ui==1.57.4 (from solara-ui[all]==1.57.4->solara->pygis)
#   Downloading solara_ui-1.57.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from solara-server==1.57.4->solara-server[dev,starlette]==1.57.4->solara->pygis) (3.29.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from solara-server==1.57.4->solara-server[dev,starlette]==1.57.4->solara->pygis) (5.10.4)
# Collecting rich-click (from solara-server==1.57.4->solara-server[dev,starlette]==1.57.4->solara->pygis)
#   Downloading rich_click-1.9.7-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.12/dist-packages (from solara-server[dev,starlette]==1.57.4->solara->pygis) (6.0.0)
# Requirement already satisfied: watchfiles in /usr/local/lib/python3.12/dist-packages (from solara-server[dev,starlette]==1.57.4->solara->pygis) (1.1.1)
# Requirement already satisfied: starlette in /usr/local/lib/python3.12/dist-packages (from solara-server[dev,starlette]==1.57.4->solara->pygis) (0.52.1)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (from solara-server[dev,starlette]==1.57.4->solara->pygis) (0.46.0)
# Requirement already satisfied: websockets in /usr/local/lib/python3.12/dist-packages (from solara-server[dev,starlette]==1.57.4->solara->pygis) (15.0.1)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from solara-ui==1.57.4->solara-ui[all]==1.57.4->solara->pygis) (4.15.0)
# Collecting reacton>=1.9 (from solara-ui==1.57.4->solara-ui[all]==1.57.4->solara->pygis)
#   Downloading reacton-1.9.1-py2.py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from solara-ui[all]==1.57.4->solara->pygis) (6.2.6)
# Requirement already satisfied: markdown in /usr/local/lib/python3.12/dist-packages (from solara-ui[all]==1.57.4->solara->pygis) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from solara-ui[all]==1.57.4->solara->pygis) (11.3.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from solara-ui[all]==1.57.4->solara->pygis) (2.20.0)
# Collecting pymdown-extensions (from solara-ui[all]==1.57.4->solara->pygis)
#   Downloading pymdown_extensions-10.21.3-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: jupyter-core>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from voila->pygis) (5.9.1)
# Collecting jupyterlab-server<3,>=2.3.0 (from voila->pygis)
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: nbclient>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from voila->pygis) (0.10.4)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in /usr/local/lib/python3.12/dist-packages (from voila->pygis) (7.17.1)
# Collecting ipytree (from whiteboxgui->pygis)
#   Downloading ipytree-0.2.2-py2.py3-none-any.whl.metadata (849 bytes)
# Collecting whitebox (from whiteboxgui->pygis)
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from anywidget->geemap>=0.36.6->pygis) (0.15.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from anywidget->geemap>=0.36.6->pygis) (4.15.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->geemap>=0.36.6->pygis) (3.10.1)
# Requirement already satisfied: google-api-python-client>=1.12.1 in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->geemap>=0.36.6->pygis) (2.194.0)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->geemap>=0.36.6->pygis) (0.3.1)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from earthengine-api>=1.6.12->geemap>=0.36.6->pygis) (0.31.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.0.0->geeadd->pygis) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth>=2.0.0->geeadd->pygis) (4.9.1)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from ipyleaflet>=0.19.2->geemap>=0.36.6->pygis) (0.20.0)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from ipyleaflet>=0.19.2->geemap>=0.36.6->pygis) (0.2.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->pygis) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel->pygis)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->pygis) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->pygis) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->pygis) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel->pygis) (0.2.0)
# Collecting comm>=0.1.3 (from ipywidgets->leafmap>=0.57.9->pygis)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->leafmap>=0.57.9->pygis)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.57.9->pygis) (3.0.16)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->jupysql->pygis) (3.0.3)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from jsbeautifier>=1.15.1->geeadd->pygis) (1.17.0)
# Collecting editorconfig>=0.12.2 (from jsbeautifier>=1.15.1->geeadd->pygis)
#   Downloading editorconfig-0.17.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->pygis) (0.4)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (4.13.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (0.25.0)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.3.0->voila->pygis) (2.18.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.3.0->voila->pygis)
#   Downloading json5-0.14.0-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.3.0->voila->pygis) (4.26.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert<8,>=6.4.5->voila->pygis) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila->pygis) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert<8,>=6.4.5->voila->pygis) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert<8,>=6.4.5->voila->pygis) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert<8,>=6.4.5->voila->pygis) (3.2.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert<8,>=6.4.5->voila->pygis) (1.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>=4.0->bash_kernel->pygis) (0.7.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from ploomber-core>=0.2.7->jupysql->pygis) (6.0.3)
# Collecting posthog>=3.0 (from ploomber-core>=0.2.7->jupysql->pygis)
#   Downloading posthog-7.14.2-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable>=3.12.0->jupysql->pygis) (0.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.3->maplibre->pygis) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.3->maplibre->pygis) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.3->maplibre->pygis) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->geemap>=0.36.6->pygis) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->geemap>=0.36.6->pygis) (3.13)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.0.0->geeadd->pygis) (4.0.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4->mapclassify->pygis) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4->mapclassify->pygis) (3.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.3.22->duckdb-engine->pygis) (3.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->pygis) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->pygis) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->pygis) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->pygis) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->pygis) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->pygis) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->pygis) (1.23.0)
# Requirement already satisfied: ratelim in /usr/local/lib/python3.12/dist-packages (from geocoder->geemap>=0.36.6->pygis) (0.1.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geemap>=0.36.6->pygis) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geemap>=0.36.6->pygis) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geemap>=0.36.6->pygis) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geemap>=0.36.6->pygis) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->geemap>=0.36.6->pygis) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->geemap>=0.36.6->pygis) (9.1.4)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila->pygis) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert<8,>=6.4.5->voila->pygis) (1.4.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap>=0.36.6->pygis) (2.30.3)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap>=0.36.6->pygis) (4.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->pygis) (0.8.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila->pygis) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila->pygis) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.3.0->voila->pygis) (0.30.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (0.1.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.0.0->geeadd->pygis) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->solara-server==1.57.4->solara-server[dev,starlette]==1.57.4->solara->pygis) (2.21.2)
# Collecting backoff>=1.10.0 (from posthog>=3.0->ploomber-core>=0.2.7->jupysql->pygis)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from posthog>=3.0->ploomber-core>=0.2.7->jupysql->pygis) (1.9.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.0.0->geeadd->pygis) (0.6.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert<8,>=6.4.5->voila->pygis) (2.8.3)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api>=1.6.12->geemap>=0.36.6->pygis) (2.5.1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api>=1.6.12->geemap>=0.36.6->pygis) (2.8.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->earthengine-api>=1.6.12->geemap>=0.36.6->pygis) (1.8.0)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->leafmap>=0.57.9->pygis) (1.7.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn->solara-server[dev,starlette]==1.57.4->solara->pygis) (0.16.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap>=0.36.6->pygis) (1.74.0)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap>=0.36.6->pygis) (5.29.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client>=1.12.1->earthengine-api>=1.6.12->geemap>=0.36.6->pygis) (1.27.2)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (25.10.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (3.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->pygis) (1.4.0)
# Downloading pygis-0.10.2-py2.py3-none-any.whl (3.4 kB)
# Downloading leafmap-0.62.0-py2.py3-none-any.whl (667 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 667.5/667.5 kB 32.8 MB/s eta 0:00:00
# Downloading duckdb-1.5.2-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (21.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 37.6 MB/s eta 0:00:00
# Downloading anymap-0.12.0-py2.py3-none-any.whl (273 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.8/273.8 kB 12.6 MB/s eta 0:00:00
# Downloading bash_kernel-0.10.0-py2.py3-none-any.whl (616 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 617.0/617.0 kB 33.6 MB/s eta 0:00:00
# Downloading duckdb_engine-0.17.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 1.5 MB/s eta 0:00:00
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading geeadd-2.1.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.2/67.2 kB 4.5 MB/s eta 0:00:00
# Downloading jupysql-0.11.1-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.1/95.1 kB 6.5 MB/s eta 0:00:00
# Downloading jupyter_server_proxy-4.5.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 2.4 MB/s eta 0:00:00
# Downloading maplibre-0.3.6-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 56.0 MB/s eta 0:00:00
# Downloading mapwidget-0.2.0-py2.py3-none-any.whl (15 kB)
# Downloading planetary_computer-1.0.0-py3-none-any.whl (14 kB)
# Downloading pmtiles-3.7.0-py3-none-any.whl (16 kB)
# Downloading solara-1.57.4-py3-none-any.whl (5.9 kB)
# Downloading solara_server-1.57.4-py3-none-any.whl (3.9 kB)
# Downloading solara_ui-1.57.4-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 48.6 MB/s eta 0:00:00
# Downloading voila-0.5.12-py3-none-any.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 58.4 MB/s eta 0:00:00
# Downloading voila_topbar-0.1.1-py3-none-any.whl (733 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 733.1/733.1 kB 33.6 MB/s eta 0:00:00
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 6.4 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading ipyvue-1.12.0-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 30.6 MB/s eta 0:00:00
# Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 68.7 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 8.1 MB/s eta 0:00:00
# Downloading jsbeautifier-1.15.4-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.7/94.7 kB 5.5 MB/s eta 0:00:00
# Downloading jupysql_plugin-0.4.5-py3-none-any.whl (192 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.8/192.8 kB 13.8 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 4.4 MB/s eta 0:00:00
# Downloading ploomber_core-0.2.27-py3-none-any.whl (22 kB)
# Downloading pystac-1.14.3-py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 13.7 MB/s eta 0:00:00
# Downloading pystac_client-0.9.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 2.2 MB/s eta 0:00:00
# Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Downloading eval_type_backport-0.3.1-py3-none-any.whl (6.1 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading ipytree-0.2.2-py2.py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 50.3 MB/s eta 0:00:00
# Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 4.4 MB/s eta 0:00:00
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading editorconfig-0.17.1-py3-none-any.whl (16 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 87.2 MB/s eta 0:00:00
# Downloading json5-0.14.0-py3-none-any.whl (36 kB)
# Downloading posthog-7.14.2-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.8/240.8 kB 15.8 MB/s eta 0:00:00
# Downloading reacton-1.9.1-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.8/108.8 kB 4.8 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 60.9 MB/s eta 0:00:00
# Downloading pymdown_extensions-10.21.3-py3-none-any.whl (269 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.0/269.0 kB 16.0 MB/s eta 0:00:00
# Downloading rich_click-1.9.7-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 3.7 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Installing collected packages: pmtiles, filetype, widgetsnbextension, whitebox, voila-topbar, simpervisor, pymdown-extensions, json5, jedi, geojson, ffmpeg-python, eval-type-backport, editorconfig, duckdb, comm, colorama, backoff, pystac, posthog, jsbeautifier, duckdb-engine, rich-click, ploomber-core, maplibre, ipywidgets, reacton, jupysql-plugin, ipyvue, ipytree, bash_kernel, whiteboxgui, pystac-client, mapwidget, jupysql, ipyvuetify, solara-ui, planetary-computer, leafmap, anymap, solara-server, geeadd, jupyterlab-server, jupyter-server-proxy, voila, solara, pygis
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.10
#     Uninstalling widgetsnbextension-3.6.10:
#       Successfully uninstalled widgetsnbextension-3.6.10
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.3.2
#     Uninstalling duckdb-1.3.2:
#       Successfully uninstalled duckdb-1.3.2
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# Successfully installed anymap-0.12.0 backoff-2.2.1 bash_kernel-0.10.0 colorama-0.4.6 comm-0.2.3 duckdb-1.5.2 duckdb-engine-0.17.0 editorconfig-0.17.1 eval-type-backport-0.3.1 ffmpeg-python-0.2.0 filetype-1.2.0 geeadd-2.1.0 geojson-3.2.0 ipytree-0.2.2 ipyvue-1.12.0 ipyvuetify-1.11.3 ipywidgets-8.1.8 jedi-0.20.0 jsbeautifier-1.15.4 json5-0.14.0 jupysql-0.11.1 jupysql-plugin-0.4.5 jupyter-server-proxy-4.5.0 jupyterlab-server-2.28.0 leafmap-0.62.0 maplibre-0.3.6 mapwidget-0.2.0 planetary-computer-1.0.0 ploomber-core-0.2.27 pmtiles-3.7.0 posthog-7.14.2 pygis-0.10.2 pymdown-extensions-10.21.3 pystac-1.14.3 pystac-client-0.9.0 reacton-1.9.1 rich-click-1.9.7 simpervisor-1.0.0 solara-1.57.4 solara-server-1.57.4 solara-ui-1.57.4 voila-0.5.12 voila-topbar-0.1.1 whitebox-2.3.6 whiteboxgui-2.3.0 widgetsnbextension-4.0.15

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Creating GeoDataFrames
#
# ### Creating Points from Coordinate Data

# %%
# Creating a GeoDataFrame from coordinate data
data = {
    "City": ["Tokyo", "New York", "London", "Paris"],
    "Latitude": [35.6895, 40.7128, 51.5074, 48.8566],
    "Longitude": [139.6917, -74.0060, -0.1278, 2.3522],
}

# First create a regular pandas DataFrame
df = pd.DataFrame(data)

# Convert to GeoDataFrame by creating Point geometries from coordinates
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))
gdf
# Out:
#        City  Latitude  Longitude                  geometry
# 0     Tokyo   35.6895   139.6917  POINT (139.6917 35.6895)
# 1  New York   40.7128   -74.0060   POINT (-74.006 40.7128)
# 2    London   51.5074    -0.1278   POINT (-0.1278 51.5074)
# 3     Paris   48.8566     2.3522    POINT (2.3522 48.8566)

# %% [markdown]
# ## Reading and Writing Geospatial Data
#
# ### Understanding Geospatial File Formats
#
# ### Reading a GeoJSON File

# %%
url = "https://github.com/opengeos/datasets/releases/download/vector/nybb.geojson"
gdf = gpd.read_file(url)
gdf.head()

# %% [markdown]
# ### Writing Geospatial Data

# %%
output_file = "nyc_boroughs.geojson"
gdf.to_file(output_file, driver="GeoJSON")
print(f"GeoDataFrame has been written to {output_file}")

# %%
# Save as Shapefile (traditional GIS format)
output_file = "nyc_boroughs.shp"
gdf.to_file(output_file)

# Save as GeoPackage (modern, single-file format)
output_file = "nyc_boroughs.gpkg"
gdf.to_file(output_file, driver="GPKG")

# %% [markdown]
# ## Projections and Coordinate Reference Systems (CRS)
#
# ### Understanding Coordinate Systems
#
# ### Checking and Understanding CRS

# %%
print(f"Current CRS: {gdf.crs}")

# %% [markdown]
# ### Reprojecting to Different Coordinate Systems

# %%
# Reproject to WGS84 (latitude/longitude) for global compatibility
gdf_4326 = gdf.to_crs(epsg=4326)
print(f"Reprojected CRS: {gdf_4326.crs}")
gdf_4326.head()

# %% [markdown]
# ## Spatial Measurements and Analysis
#
# ### Preparing Data for Accurate Measurements

# %%
# Reproject to Web Mercator for accurate area calculations in square meters
gdf = gdf.to_crs("EPSG:3857")

# Set BoroName as index for easier data access
gdf = gdf.set_index("BoroName")
print(f"Now using CRS: {gdf.crs}")

# %% [markdown]
# ### Calculating Areas

# %%
# Calculate area in square meters
gdf["area"] = gdf.area

# Convert to more readable units (square kilometers)
gdf["area_km2"] = gdf["area"] / 1_000_000

# Display results sorted by area
gdf[["area", "area_km2"]].sort_values("area_km2", ascending=False)

# %% [markdown]
# ### Extracting Geometric Features

# %%
# Extract boundary lines from polygons
gdf["boundary"] = gdf.boundary

# Calculate centroids (geometric centers)
gdf["centroid"] = gdf.centroid

# Display the geometric features
gdf[["boundary", "centroid"]].head()

# %% [markdown]
# ### Distance Calculations

# %%
# Use Manhattan's centroid as the reference point
manhattan_centroid = gdf.loc["Manhattan", "centroid"]

# Calculate distance from each borough centroid to Manhattan
gdf["distance_to_manhattan"] = gdf["centroid"].distance(manhattan_centroid)

# Convert to kilometers and display results
gdf["distance_to_manhattan_km"] = gdf["distance_to_manhattan"] / 1000

gdf[["distance_to_manhattan_km"]].sort_values("distance_to_manhattan_km")

# %% [markdown]
# ### Statistical Analysis of Spatial Data

# %%
# Calculate summary statistics
mean_distance = gdf["distance_to_manhattan_km"].mean()
max_distance = gdf["distance_to_manhattan_km"].max()
total_area = gdf["area_km2"].sum()

print(f"Mean distance to Manhattan: {mean_distance:.2f} km")
print(f"Maximum distance to Manhattan: {max_distance:.2f} km")
print(f"Total NYC area: {total_area:.2f} km²")

# %% [markdown]
# ## Visualizing Geospatial Data
#
# ### Setting Up Plotting Environment

# %%
import matplotlib.pyplot as plt

# Set high resolution for better quality plots
plt.rcParams["figure.dpi"] = 150

# %% [markdown]
# ### Thematic Mapping

# %%
# Create a choropleth map showing borough areas
fig, ax = plt.subplots(figsize=(10, 6))

gdf.plot(
    column="area_km2",
    ax=ax,
    legend=True,
    cmap="YlOrRd",  # Yellow-Orange-Red colormap
    edgecolor="black",
    linewidth=0.5,
)

plt.title("NYC Boroughs by Area (km²)", fontsize=16, fontweight="bold")
plt.axis("off")  # Remove coordinate axes for cleaner appearance
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Multi-Layer Visualization

# %%
# Create a comprehensive map with multiple layers
fig, ax = plt.subplots(figsize=(10, 6))

# Plot borough boundaries as base layer
gdf["geometry"].plot(
    ax=ax, color="lightblue", edgecolor="navy", linewidth=1.5, alpha=0.7
)

# Add centroids as point layer
gdf["centroid"].plot(
    ax=ax, color="red", markersize=80, edgecolor="darkred", linewidth=1
)

# Add borough labels
for idx, row in gdf.iterrows():
    # Get centroid coordinates for label placement
    x = row.centroid.x
    y = row.centroid.y
    ax.annotate(
        idx,
        (x, y),
        xytext=(5, 5),
        textcoords="offset points",
        fontsize=10,
        fontweight="bold",
        bbox=dict(boxstyle="round,pad=0.3", facecolor="white", alpha=0.8),
    )

plt.title("NYC Borough Boundaries and Centroids", fontsize=16, fontweight="bold")
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interactive Visualization

# %%
# Create an interactive map using Folium integration
m = gdf.explore(
    column="area_km2",
    cmap="YlOrRd",
    tooltip=["area_km2", "distance_to_manhattan_km"],
    popup=True,
    legend=True,
)
m

# %% [markdown]
# ## Advanced Geometric Operations
#
# ### Buffer Analysis

# %%
# Create 3-kilometer buffer zones around each borough
buffer_distance = 3000  # meters
gdf["buffered"] = gdf.buffer(buffer_distance)

print(f"Created {buffer_distance/1000} km buffer zones around each borough")

# %%
# Visualize original vs buffered geometries
fig, ax = plt.subplots(figsize=(10, 6))

# Plot buffered areas first (background)
gdf["buffered"].plot(
    ax=ax,
    alpha=0.3,
    color="orange",
    edgecolor="red",
    linewidth=1,
    label="3km Buffer Zone",
)

# Plot original geometries on top
gdf["geometry"].plot(
    ax=ax,
    color="lightblue",
    edgecolor="navy",
    linewidth=1.5,
    label="Original Boundaries",
)

plt.title("NYC Boroughs: Original vs 3km Buffer Zones", fontsize=16, fontweight="bold")
plt.legend(loc="upper right")
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Convex Hull Analysis

# %%
# Calculate convex hulls for each borough
gdf["convex_hull"] = gdf.convex_hull

# Compare areas between original shapes and convex hulls
gdf["convex_hull_area"] = gdf["convex_hull"].area / 1_000_000  # Convert to km²
gdf["area_ratio"] = gdf["convex_hull_area"] / gdf["area_km2"]

print("Convex Hull Analysis:")
print(gdf[["area_km2", "convex_hull_area", "area_ratio"]].round(2))

# %%
# Create comparison visualization
fig, ax = plt.subplots(figsize=(10, 6))

# Plot original geometries
gdf["geometry"].plot(
    ax=ax, color="lightblue", edgecolor="navy", linewidth=2, label="Original Shape"
)

# Plot convex hulls as outlines
gdf["convex_hull"].plot(
    ax=ax,
    facecolor="none",
    edgecolor="red",
    linewidth=2,
    linestyle="--",
    label="Convex Hull",
)

plt.title(
    "NYC Boroughs: Original Shapes vs Convex Hulls", fontsize=16, fontweight="bold"
)
plt.legend(loc="upper right")
plt.axis("off")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Spatial Relationships and Queries
#
# ### Intersection Analysis

# %%
# Test which buffered boroughs intersect with Manhattan's original boundary
manhattan_geom = gdf.loc["Manhattan", "geometry"]

gdf["intersects_manhattan"] = gdf["buffered"].intersects(manhattan_geom)
gdf["touches_manhattan"] = gdf["geometry"].touches(manhattan_geom)

# Display results
intersection_results = gdf[["intersects_manhattan", "touches_manhattan"]]
intersection_results

# %% [markdown]
# ### Containment and Spatial Validation

# %%
# Verify that centroids fall within their respective borough boundaries
gdf["centroid_within_borough"] = gdf["centroid"].within(gdf["geometry"])

# Check for any anomalies
anomalies = gdf[~gdf["centroid_within_borough"]]
if len(anomalies) > 0:
    print("Warning: Some centroids fall outside their borough boundaries")
    print(anomalies.index.tolist())
else:
    print("✓ All centroids correctly fall within their borough boundaries")

# %% [markdown]
# ## Best Practices and Performance Considerations
#
# ### Coordinate System Management
#
# ### Memory and Performance
#
# ### Data Validation
#
# ## Key Takeaways
#
# ## Exercises
#
# ### Exercise 1: Creating and Manipulating GeoDataFrames with GeoPandas

# %% [markdown]
# ### Exercise 2: Combining NumPy, Pandas, and GeoPandas
